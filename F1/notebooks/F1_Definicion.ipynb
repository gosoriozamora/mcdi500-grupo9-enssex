# %% [markdown]
# # Fase 1: Definición del proyecto y configuración del entorno
#
# **Asignatura:** Programación para la Ciencia de Datos
# **Grupo:** 9
# **Integrantes:** Guillermo Osorio Zamora y Karla Patricia Pizarro Correa
#
# ## Presentación
#
# Este proyecto utiliza los datos de ENSSEX 2022–2023 para estudiar
# la valoración de la vida sexual y el bienestar mental o emocional
# percibido en personas que conviven con su pareja, considerando
# su grado de dependencia económica.
#
# ## Pregunta de investigación
#
# ¿Cómo varían la valoración de la vida sexual y el bienestar mental
# o emocional percibido según el grado de dependencia económica de
# la pareja entre las personas encuestadas en ENSSEX 2022–2023 que
# conviven con ella?
#
# ## Objetivo general
#
# Analizar cómo varían la valoración de la vida sexual y el bienestar
# mental o emocional percibido según el grado de dependencia económica
# de la pareja en personas encuestadas en ENSSEX 2022–2023 que conviven
# con ella.

# %% [markdown]
# ## Comprobación inicial del entorno
#
# Comprobamos la versión de Python, el intérprete utilizado y la
# carpeta de ejecución. También consultamos las versiones de pandas
# y pyreadstat para contrastarlas con las dependencias del proyecto.
#
# Esta comprobación permite verificar que el notebook utiliza el
# entorno virtual preparado para el trabajo.

# %%
import sys
from pathlib import Path
from importlib.metadata import version

print("Python:", sys.version.split()[0])
print("Intérprete:", sys.executable)
print("Carpeta de ejecución:", Path.cwd())
print("pandas:", version("pandas"))
print("pyreadstat:", version("pyreadstat"))

assert sys.prefix != sys.base_prefix, "Seleccionar el kernel del entorno virtual."
# Out:
# Python: 3.13.15
# Intérprete: C:\Users\Karlita\Proyectos\proyecto-enssex\.venv\Scripts\python.exe
# Carpeta de ejecución: C:\Users\Karlita\Proyectos\proyecto-enssex\F1\notebooks
# pandas: 3.0.5
# pyreadstat: 1.3.6
